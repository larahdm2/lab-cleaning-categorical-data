# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# # 1. Open the notebook created for Lab-cleaning-numerical-data.

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
cols = []
for colname in customer_df.columns:
    cols.append(colname.lower().replace(' ', '_'))
customer_df.columns = cols

customer_df.rename(columns={'employmentstatus':'employment_status'}, inplace = True)

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'], errors='coerce')

# %%
numerical_df = customer_df.select_dtypes(include = np.number)

# %%
def discrete_continuous(df):
    
    discrete_df = pd.DataFrame()
    continuous_df = pd.DataFrame()
    
    for column in df.columns:
        if df[column].nunique() <= 100:
            discrete_df[column] = df[column]
        else:
            continuous_df[column] = df[column]
    
    return discrete_df, continuous_df

# %%
discrete_df, continuous_df = discrete_continuous(numerical_df)

# %%
def plot(df):
    for column in df.columns:
        if df[column].nunique() <= 100:
            plt.figure(figsize=(20, 6))
            sns.countplot(x=df[column], data=df)
            plt.title(f'Count Plot of {column}')
            plt.xticks(rotation=90)  # Rotate x-axis labels vertically
            plt.show()
        else:
            plt.figure(figsize=(8, 6))
            sns.histplot(x=df[column], bins=20, kde=True)
            plt.title(f'Histogram of {column}')
            plt.xlabel(column)
            plt.ylabel('Frequency')
            plt.show()

# %%
continuous_df = continuous_df[(continuous_df['customer_lifetime_value'] <= 65000) & (continuous_df['total_claim_amount'] <= 2500)]
customer_df = customer_df[(customer_df['customer_lifetime_value'] <= 65000) & (customer_df['total_claim_amount'] <= 2500)]
numerical_df = numerical_df[(numerical_df['customer_lifetime_value'] <= 65000) & (numerical_df['total_claim_amount'] <= 2500)]

# %%
numerical_df.to_csv('numerical_230821.csv', index=False)

# %% [markdown]
# # 2. Find all of the categorical data. Save it in a categorical_df variable.

# %%
categorical_df = customer_df.select_dtypes(include = np.object)
categorical_df.drop('customer', axis=1, inplace=True)
categorical_df
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_10536\806269968.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical_df = customer_df.select_dtypes(include = np.object)
#            state response  coverage education employment_status gender  \
# 0     Washington       No     Basic  Bachelor          Employed      F
# 1        Arizona       No  Extended  Bachelor        Unemployed      F
# 2         Nevada       No   Premium  Bachelor          Employed      F
# 3     California       No     Basic  Bachelor        Unemployed      M
# 4     Washington       No     Basic  Bachelor          Employed      M
# ...          ...      ...       ...       ...               ...    ...
# 9129  California       No     Basic  Bachelor          Employed      M
# 9130  California      Yes  Extended   College          Employed      F
# 9131  California       No  Extended  Bachelor        Unemployed      M
# 9132  California       No  Extended   College          Employed      M
# 9133  California       No  Extended   College        Unemployed      M
#
#      location_code marital_status     policy_type        policy  \
# 0         Suburban        Married  Corporate Auto  Corporate L3
# 1         Suburban         Single   Personal Auto   Personal L3
# 2         Suburban        Married   Personal Auto   Personal L3
# 3         Suburban        Married  Corporate Auto  Corporate L2
# 4            Rural         Single   Personal Auto   Personal L1
# ...            ...            ...             ...           ...
# 9129         Urban        Married   Personal Auto   Personal L1
# 9130      Suburban       Divorced  Corporate Auto  Corporate L3
# 9131      Suburban         Single  Corporate Auto  Corporate L2
# 9132      Suburban        Married   Personal Auto   Personal L2
# 9133      Suburban         Single  Corporate Auto  Corporate L3
#
#      renew_offer_type sales_channel  vehicle_class vehicle_size
# 0              Offer1         Agent   Two-Door Car      Medsize
# 1              Offer3         Agent  Four-Door Car      Medsize
# 2              Offer1         Agent   Two-Door Car      Medsize
# 3              Offer1   Call Center            SUV      Medsize
# 4              Offer1         Agent  Four-Door Car      Medsize
# ...               ...           ...            ...          ...
# 9129           Offer2           Web  Four-Door Car      Medsize
# 9130           Offer1        Branch  Four-Door Car      Medsize
# 9131           Offer1        Branch  Four-Door Car      Medsize
# 9132           Offer3        Branch  Four-Door Car        Large
# 9133           Offer4   Call Center   Two-Door Car      Medsize
#
# [9126 rows x 14 columns]

# %% [markdown]
# # 3. Check for NaN values and decide what to do with them, do it now.

# %%
categorical_df.isna().sum()
# Out:
# state                0
# response             0
# coverage             0
# education            0
# employment_status    0
# gender               0
# location_code        0
# marital_status       0
# policy_type          0
# policy               0
# renew_offer_type     0
# sales_channel        0
# vehicle_class        0
# vehicle_size         0
# dtype: int64

# %% [markdown]
# # 4. Check all unique values of columns.

# %%
for column in categorical_df.columns:
    unique_values = categorical_df[column].unique()
    print(f"Unique values in '{column}': {unique_values}")
# Out:
# Unique values in 'state': ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# Unique values in 'response': ['No' 'Yes']
# Unique values in 'coverage': ['Basic' 'Extended' 'Premium']
# Unique values in 'education': ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# Unique values in 'employment_status': ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# Unique values in 'gender': ['F' 'M']
# Unique values in 'location_code': ['Suburban' 'Rural' 'Urban']
# Unique values in 'marital_status': ['Married' 'Single' 'Divorced']
# Unique values in 'policy_type': ['Corporate Auto' 'Personal Auto' 'Special Auto']
# Unique values in 'policy': ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'
#  'Corporate L1' 'Personal L2' 'Special L1' 'Special L3']
# Unique values in 'renew_offer_type': ['Offer1' 'Offer3' 'Offer2' 'Offer4']
# Unique values in 'sales_channel': ['Agent' 'Call Center' 'Web' 'Branch']
# Unique values in 'vehicle_class': ['Two-Door Car' 'Four-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car']
# Unique values in 'vehicle_size': ['Medsize' 'Small' 'Large']

# %% [markdown]
# # 5. Check dtypes. Do they all make sense as categorical data?

# %%
for column in categorical_df.columns:
    dtypes = categorical_df[column].dtype
    print(f"Type of '{column}': {dtypes}")
# Out:
# Type of 'state': object
# Type of 'response': object
# Type of 'coverage': object
# Type of 'education': object
# Type of 'employment_status': object
# Type of 'gender': object
# Type of 'location_code': object
# Type of 'marital_status': object
# Type of 'policy_type': object
# Type of 'policy': object
# Type of 'renew_offer_type': object
# Type of 'sales_channel': object
# Type of 'vehicle_class': object
# Type of 'vehicle_size': object

# %% [markdown]
# Apart from "customer" that I already dropped, yes. "customer" values are unique, so it´s not categorical data.

# %% [markdown]
# # 6. Does any column contain alpha and numeric data? Decide how to clean it and do it now.

# %% [markdown]
# Yes, but I think it´s right. Nonetheless, we can shorter "Offer1" to "O1".

# %%
substitutions = {
    'Offer1': 'O1',
    'Offer2': 'O2',
    'Offer3': 'O3',
    'Offer4': 'O4'
}

categorical_df['renew_offer_type'] = categorical_df['renew_offer_type'].map(substitutions)

categorical_df['renew_offer_type']
# Out:
# 0       O1
# 1       O3
# 2       O1
# 3       O1
# 4       O1
#         ..
# 9129    O2
# 9130    O1
# 9131    O1
# 9132    O3
# 9133    O4
# Name: renew_offer_type, Length: 9126, dtype: object

# %% [markdown]
# # 7. Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions and do it now.

# %%
categorical_df['employment_status'].value_counts()
# Out:
# Employed         5693
# Unemployed       2315
# Medical Leave     431
# Disabled          405
# Retired           282
# Name: employment_status, dtype: int64

# %% [markdown]
# We could group column employment_status into 'active' or 'inactive'.

# %%
substitutions2 = {
    'Employed': 'Active',
    'Unemployed': 'Inactive',
    'Medical Leave': 'Inactive',
    'Disabled': 'Inactive',
    'Retired': 'Inactive'
}

categorical_df['employment_status'] = categorical_df['employment_status'].map(substitutions2)

# %%
categorical_df['employment_status'].unique()
# Out:
# array(['Active', 'Inactive'], dtype=object)

# %% [markdown]
# # 8. Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

# %% [markdown]
# Unique values in 'policy_type': ['Corporate Auto' 'Personal Auto' 'Special Auto']
#
#
#
# Unique values in 'policy': ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'

# %%
categorical_df.head(60)
# Out:
#          state response  coverage             education employment_status  \
# 0   Washington       No     Basic              Bachelor            Active
# 1      Arizona       No  Extended              Bachelor          Inactive
# 2       Nevada       No   Premium              Bachelor            Active
# 3   California       No     Basic              Bachelor          Inactive
# 4   Washington       No     Basic              Bachelor            Active
# 5       Oregon      Yes     Basic              Bachelor            Active
# 6       Oregon      Yes     Basic               College            Active
# 7      Arizona       No   Premium                Master          Inactive
# 8       Oregon      Yes     Basic              Bachelor          Inactive
# 9       Oregon       No  Extended               College            Active
# 10  California       No     Basic               College          Inactive
# 11  California       No     Basic               College          Inactive
# 12  California       No   Premium                Master            Active
# 13     Arizona      Yes     Basic  High School or Below            Active
# 14  California       No     Basic               College            Active
# 15      Oregon       No     Basic              Bachelor            Active
# 16      Nevada       No     Basic  High School or Below          Inactive
# 17  California       No     Basic               College          Inactive
# 18      Oregon       No     Basic               College            Active
# 19  California       No   Premium  High School or Below            Active
# 20      Oregon       No     Basic  High School or Below            Active
# 21  Washington       No  Extended              Bachelor          Inactive
# 22     Arizona      Yes     Basic              Bachelor          Inactive
# 23      Nevada       No     Basic              Bachelor          Inactive
# 24  California       No     Basic              Bachelor          Inactive
# 25      Oregon       No     Basic               College            Active
# 26  California       No   Premium              Bachelor          Inactive
# 27  Washington       No  Extended                Master          Inactive
# 28     Arizona       No   Premium               College            Active
# 29      Oregon       No  Extended                Master            Active
# 30     Arizona       No     Basic               College            Active
# 31      Nevada       No  Extended  High School or Below            Active
# 32  California       No     Basic              Bachelor          Inactive
# 33  Washington       No     Basic              Bachelor            Active
# 34      Oregon       No     Basic              Bachelor            Active
# 35     Arizona       No     Basic  High School or Below            Active
# 36  California       No   Premium              Bachelor            Active
# 37      Oregon       No  Extended                Master            Active
# 38      Oregon       No  Extended              Bachelor          Inactive
# 39     Arizona       No     Basic  High School or Below            Active
# 40      Nevada       No     Basic  High School or Below          Inactive
# 41      Oregon      Yes     Basic               College            Active
# 42  California      Yes  Extended              Bachelor            Active
# 43     Arizona       No     Basic  High School or Below            Active
# 44  Washington       No     Basic               College            Active
# 45      Oregon       No   Premium                Doctor          Inactive
# 46     Arizona       No     Basic              Bachelor          Inactive
# 47      Oregon       No     Basic  High School or Below            Active
# 48  California       No  Extended              Bachelor          Inactive
# 49     Arizona       No     Basic  High School or Below          Inactive
# 50      Oregon       No     Basic               College            Active
# 51  California      Yes     Basic              Bachelor            Active
# 52      Nevada       No     Basic  High School or Below            Active
# 53  Washington       No     Basic              Bachelor            Active
# 54  California       No   Premium              Bachelor          Inactive
# 55     Arizona       No  Extended               College            Active
# 56  California       No     Basic               College            Active
# 57     Arizona       No     Basic  High School or Below          Inactive
# 58      Oregon       No  Extended  High School or Below          Inactive
# 59      Oregon       No   Premium                Master          Inactive
#
#    gender location_code marital_status     policy_type        policy  \
# 0       F      Suburban        Married  Corporate Auto  Corporate L3
# 1       F      Suburban         Single   Personal Auto   Personal L3
# 2       F      Suburban        Married   Personal Auto   Personal L3
# 3       M      Suburban        Married  Corporate Auto  Corporate L2
# 4       M         Rural         Single   Personal Auto   Personal L1
# 5       F         Rural        Married   Personal Auto   Personal L3
# 6       F      Suburban        Married  Corporate Auto  Corporate L3
# 7       M         Urban         Single  Corporate Auto  Corporate L3
# 8       M      Suburban       Divorced  Corporate Auto  Corporate L3
# 9       F         Urban        Married    Special Auto    Special L2
# 10      M      Suburban         Single   Personal Auto   Personal L3
# 11      F      Suburban        Married   Personal Auto   Personal L3
# 12      M         Urban        Married  Corporate Auto  Corporate L1
# 13      M      Suburban        Married  Corporate Auto  Corporate L3
# 14      M         Urban         Single  Corporate Auto  Corporate L3
# 15      F         Rural        Married  Corporate Auto  Corporate L2
# 16      M      Suburban        Married   Personal Auto   Personal L3
# 17      M      Suburban        Married   Personal Auto   Personal L2
# 18      M         Urban        Married   Personal Auto   Personal L2
# 19      F      Suburban        Married  Corporate Auto  Corporate L2
# 20      M      Suburban         Single   Personal Auto   Personal L2
# 21      F      Suburban       Divorced   Personal Auto   Personal L3
# 22      M      Suburban       Divorced   Personal Auto   Personal L3
# 23      F      Suburban         Single  Corporate Auto  Corporate L3
# 24      F      Suburban        Married  Corporate Auto  Corporate L2
# 25      M      Suburban        Married   Personal Auto   Personal L3
# 26      F      Suburban         Single   Personal Auto   Personal L3
# 27      F         Urban        Married  Corporate Auto  Corporate L1
# 28      F      Suburban         Single   Personal Auto   Personal L3
# 29      F      Suburban        Married   Personal Auto   Personal L3
# 30      M      Suburban        Married   Personal Auto   Personal L2
# 31      M         Urban        Married  Corporate Auto  Corporate L2
# 32      M         Urban        Married   Personal Auto   Personal L3
# 33      M      Suburban        Married  Corporate Auto  Corporate L2
# 34      F         Rural        Married  Corporate Auto  Corporate L1
# 35      F         Urban        Married   Personal Auto   Personal L1
# 36      M      Suburban        Married   Personal Auto   Personal L3
# 37      F      Suburban        Married   Personal Auto   Personal L3
# 38      M      Suburban         Single   Personal Auto   Personal L2
# 39      M         Rural       Divorced   Personal Auto   Personal L3
# 40      F      Suburban        Married  Corporate Auto  Corporate L3
# 41      F         Rural         Single  Corporate Auto  Corporate L3
# 42      F      Suburban        Married   Personal Auto   Personal L2
# 43      M      Suburban        Married   Personal Auto   Personal L2
# 44      M      Suburban        Married    Special Auto    Special L2
# 45      F         Rural        Married   Personal Auto   Personal L2
# 46      M      Suburban         Single   Personal Auto   Personal L3
# 47      F      Suburban         Single   Personal Auto   Personal L2
# 48      F      Suburban        Married  Corporate Auto  Corporate L2
# 49      F      Suburban        Married   Personal Auto   Personal L2
# 50      M      Suburban        Married   Personal Auto   Personal L2
# 51      F      Suburban       Divorced  Corporate Auto  Corporate L1
# 52      F         Rural        Married    Special Auto    Special L1
# 53      M      Suburban         Single   Personal Auto   Personal L3
# 54      M      Suburban        Married   Personal Auto   Personal L2
# 55      F      Suburban       Divorced  Corporate Auto  Corporate L3
# 56      M         Urban        Married    Special Auto    Special L2
# 57      F      Suburban        Married   Personal Auto   Personal L2
# 58      F      Suburban       Divorced   Personal Auto   Personal L3
# 59      F      Suburban       Divorced   Personal Auto   Personal L1
#
#    renew_offer_type sales_channel  vehicle_class vehicle_size
# 0                O1         Agent   Two-Door Car      Medsize
# 1                O3         Agent  Four-Door Car      Medsize
# 2                O1         Agent   Two-Door Car      Medsize
# 3                O1   Call Center            SUV      Medsize
# 4                O1         Agent  Four-Door Car      Medsize
# 5                O2           Web   Two-Door Car      Medsize
# 6                O1         Agent  Four-Door Car      Medsize
# 7                O1         Agent  Four-Door Car      Medsize
# 8                O1         Agent  Four-Door Car      Medsize
# 9                O2        Branch  Four-Door Car      Medsize
# 10               O1         Agent  Four-Door Car        Small
# 11               O2         Agent            SUV      Medsize
# 12               O2         Agent  Four-Door Car      Medsize
# 13               O2        Branch            SUV      Medsize
# 14               O4   Call Center  Four-Door Car      Medsize
# 15               O2        Branch  Four-Door Car      Medsize
# 16               O2   Call Center   Two-Door Car      Medsize
# 17               O3   Call Center            SUV      Medsize
# 18               O2        Branch  Four-Door Car      Medsize
# 19               O1   Call Center  Four-Door Car        Small
# 20               O1        Branch   Two-Door Car      Medsize
# 21               O4   Call Center  Four-Door Car      Medsize
# 22               O1         Agent  Four-Door Car      Medsize
# 23               O1        Branch  Four-Door Car      Medsize
# 24               O2        Branch  Four-Door Car      Medsize
# 25               O2   Call Center  Four-Door Car        Large
# 26               O1         Agent  Four-Door Car        Small
# 27               O1        Branch            SUV      Medsize
# 28               O1   Call Center  Four-Door Car        Large
# 29               O2        Branch  Four-Door Car        Small
# 30               O4   Call Center  Four-Door Car        Small
# 31               O2         Agent     Luxury SUV      Medsize
# 32               O1   Call Center  Four-Door Car      Medsize
# 33               O1         Agent   Two-Door Car        Small
# 34               O3           Web  Four-Door Car      Medsize
# 35               O1        Branch  Four-Door Car      Medsize
# 36               O1         Agent  Four-Door Car        Small
# 37               O2           Web  Four-Door Car        Small
# 38               O3         Agent   Two-Door Car        Small
# 39               O1   Call Center  Four-Door Car      Medsize
# 40               O3   Call Center   Two-Door Car      Medsize
# 41               O2         Agent   Two-Door Car      Medsize
# 42               O2         Agent  Four-Door Car        Small
# 43               O4         Agent     Sports Car      Medsize
# 44               O2   Call Center  Four-Door Car        Large
# 45               O1        Branch            SUV      Medsize
# 46               O3   Call Center  Four-Door Car      Medsize
# 47               O4         Agent   Two-Door Car      Medsize
# 48               O2   Call Center  Four-Door Car      Medsize
# 49               O4        Branch  Four-Door Car      Medsize
# 50               O1         Agent            SUV        Small
# 51               O1           Web            SUV      Medsize
# 52               O4        Branch  Four-Door Car      Medsize
# 53               O4         Agent  Four-Door Car      Medsize
# 54               O1        Branch  Four-Door Car        Small
# 55               O3   Call Center  Four-Door Car        Small
# 56               O2        Branch  Four-Door Car      Medsize
# 57               O1   Call Center            SUV        Small
# 58               O1   Call Center            SUV      Medsize
# 59               O1         Agent  Four-Door Car      Medsize

# %% [markdown]
# We can drop the "policy_type" column because the information is already present in the "policy" column.

# %% [markdown]
# # 9. Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.

# %%
for column in categorical_df.columns:
    print(f"Unique values in '{column}':")
    unique_values_count = categorical_df[column].value_counts()
    print(unique_values_count)
    print()
# Out:
# Unique values in 'state':
# California    3149
# Oregon        2599
# Arizona       1702
# Nevada         880
# Washington     796
# Name: state, dtype: int64
#
# Unique values in 'response':
# No     7818
# Yes    1308
# Name: response, dtype: int64
#
# Unique values in 'coverage':
# Basic       5567
# Extended    2737
# Premium      822
# Name: coverage, dtype: int64
#
# Unique values in 'education':
# Bachelor                2744
# College                 2681
# High School or Below    2618
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
#
# Unique values in 'employment_status':
# Active      5693
# Inactive    3433
# Name: employment_status, dtype: int64
#
# Unique values in 'gender':
# F    4657
# M    4469
# Name: gender, dtype: int64
#
# Unique values in 'location_code':
# Suburban    5772
# Rural       1772
# Urban       1582
# Name: location_code, dtype: int64
#
# Unique values in 'marital_status':
# Married     5294
# Single      2463
# Divorced    1369
# Name: marital_status, dtype: int64
#
# Unique values in 'policy_type':
# Personal Auto     6781
# Corporate Auto    1967
# Special Auto       378
# Name: policy_type, dtype: int64
#
# Unique values in 'policy':
# Personal L3     3422
# Personal L2     2121
# Personal L1     1238
# Corporate L3    1013
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64
#
# Unique values in 'renew_offer_type':
# O1    3746
# O2    2925
# O3    1432
# O4    1023
# Name: renew_offer_type, dtype: int64
#
# Unique values in 'sales_channel':
# Agent          3474
# Branch         2565
# Call Center    1763
# Web            1324
# Name: sales_channel, dtype: int64
#
# Unique values in 'vehicle_class':
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        483
# Luxury SUV        180
# Luxury Car        160
# Name: vehicle_class, dtype: int64
#
# Unique values in 'vehicle_size':
# Medsize    6417
# Small      1763
# Large       946
# Name: vehicle_size, dtype: int64

# %% [markdown]
# We can group values that don´t represent a high percentage of the data.

# %%
substitutions3 = {
    'Bachelor': 'Bachelor',
    'College': 'College',
    'High School or Below': 'High School or Below',
    'Master': 'Higher',
    'Doctor': 'Higher'
}

categorical_df['education'] = categorical_df['education'].map(substitutions3)

# %%
categorical_df['education']
# Out:
# 0       Bachelor
# 1       Bachelor
# 2       Bachelor
# 3       Bachelor
# 4       Bachelor
#           ...
# 9129    Bachelor
# 9130     College
# 9131    Bachelor
# 9132     College
# 9133     College
# Name: education, Length: 9126, dtype: object

# %%
substitutions4 = {
    'Four-Door Car': 'Four-Door Car',
    'Two-Door Car': 'Two-Door Car',
    'SUV': 'SUV',
    'Sports Car': 'Sports Car',
    'Luxury SUV': 'Luxury',
    'Luxury Car': 'Luxury'
}
categorical_df['vehicle_class'] = categorical_df['vehicle_class'].map(substitutions4)

# %%
categorical_df['vehicle_class']
# Out:
# 0        Two-Door Car
# 1       Four-Door Car
# 2        Two-Door Car
# 3                 SUV
# 4       Four-Door Car
#             ...
# 9129    Four-Door Car
# 9130    Four-Door Car
# 9131    Four-Door Car
# 9132    Four-Door Car
# 9133     Two-Door Car
# Name: vehicle_class, Length: 9126, dtype: object

# %%
# Checking I did everything right
categorical_df.isna().sum()
# Out:
# state                0
# response             0
# coverage             0
# education            0
# employment_status    0
# gender               0
# location_code        0
# marital_status       0
# policy_type          0
# policy               0
# renew_offer_type     0
# sales_channel        0
# vehicle_class        0
# vehicle_size         0
# dtype: int64

# %% [markdown]
# # 10. Save the cleaned catagorical dataframe as categorical.csv You will use this file again this week.

# %%
categorical_df.to_csv('categorical_230821.csv', index=False)
